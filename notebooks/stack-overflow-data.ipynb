# %%
import pandas as pd

# %%
f = pd.read_csv('data/data/data.csv')

# %%
df = pd.DataFrame(f)
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
pd_schema = pd.read_csv('data/schema.csv' , index_col="qname")

# %%
pd_schema.sort_index()
# Out:
#                  qid                                           question  \
# qname
# AIAcc         QID324  For the AI tools you use as part of your devel...
# AIBen         QID316  How much do you trust the accuracy of the outp...
# AIDev         QID328  Which <b>AI-powered developer tools</b> did yo...
# AINext        QID320  Thinking about how your workflow and process c...
# AIOpen        QID321  Please describe how you would expect your work...
# ...              ...                                                ...
# ToolsTech     QID275  Which <b>developer </b><strong>tools for compi...
# Webframe      QID264  Which <b>web frameworks and web technologies</...
# WorkExp       QID288  How many years of working experience do you have?
# YearsCode      QID32  Including any education, how many years have y...
# YearsCodePro   QID34  NOT including education, how many years have y...
#
#              force_resp    type selector
# qname
# AIAcc             False      MC     MAVR
# ...

# %%
pd.set_option('display.max_columns', 84)

# %%
pd.set_option('display.max_rows', 84)

# %%
df[df.EdLevel == 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)']
# Out:
#        ResponseId     Q120                      MainBranch              Age  \
# 1               2  I agree  I am a developer by profession  25-34 years old
# 2               3  I agree  I am a developer by profession  45-54 years old
# 3               4  I agree  I am a developer by profession  25-34 years old
# 4               5  I agree  I am a developer by profession  25-34 years old
# 7               8  I agree  I am a developer by profession  25-34 years old
# ...           ...      ...                             ...              ...
# 89175       89176  I agree  I am a developer by profession  25-34 years old
# 89176       89177  I agree  I am a developer by profession  18-24 years old
# 89178       89179  I agree  I am a developer by profession  45-54 years old
# 89180       89181  I agree  I am a developer by profession  18-24 years old
# 89183       89184  I agree  I am a developer by profession  35-44 years old
#
# ...

# %%
df.count()
# Out:
# ResponseId                             89184
# Q120                                   89184
# MainBranch                             89184
# Age                                    89184
# Employment                             87898
# RemoteWork                             73810
# CodingActivities                       73764
# EdLevel                                87973
# LearnCode                              87663
# LearnCodeOnline                        70084
# LearnCodeCoursesCert                   37076
# YearsCode                              87435
# YearsCodePro                           66136
# DevType                                76872
# OrgSize                                65043
# PurchaseInfluence                      64964
# TechList                               60851
# BuyNewTool                             83009
# Country                                87973
# Currency                               65334
# CompTotal                              48225
# ...

# %%
df[df.EdLevel == 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)']
# Out:
#        ResponseId     Q120                      MainBranch              Age  \
# 1               2  I agree  I am a developer by profession  25-34 years old
# 2               3  I agree  I am a developer by profession  45-54 years old
# 3               4  I agree  I am a developer by profession  25-34 years old
# 4               5  I agree  I am a developer by profession  25-34 years old
# 7               8  I agree  I am a developer by profession  25-34 years old
# ...           ...      ...                             ...              ...
# 89175       89176  I agree  I am a developer by profession  25-34 years old
# 89176       89177  I agree  I am a developer by profession  18-24 years old
# 89178       89179  I agree  I am a developer by profession  45-54 years old
# 89180       89181  I agree  I am a developer by profession  18-24 years old
# 89183       89184  I agree  I am a developer by profession  35-44 years old
#
# ...

# %%
df[(df.EdLevel == 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)'),'Age']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Documents/Code/coding-tasks/python-samples/pandas-sample/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 89179    False
# 89180     True
# 89181    False
# 89182    False
# 89183     True
# Name: EdLevel, Length: 89184, dtype: bool, 'Age')' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# ...

# %%
c = (df.EdLevel == 'Bachelor’s degree (B.A., B.S., B.Eng., etc.)')

# %%
c
# Out:
# 0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 89179    False
# 89180     True
# 89181    False
# 89182    False
# 89183     True
# Name: EdLevel, Length: 89184, dtype: bool

# %%
df[c,'MainBranch']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Documents/Code/coding-tasks/python-samples/pandas-sample/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0        False
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 89179    False
# 89180     True
# 89181    False
# 89182    False
# 89183     True
# Name: EdLevel, Length: 89184, dtype: bool, 'MainBranch')' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# ...

# %%
df['Age' == '18-24 years old']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/Code/coding-tasks/python-samples/pandas-sample/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 1
# ...

# %%
df.Age
# Out:
# 0           18-24 years old
# 1           25-34 years old
# 2           45-54 years old
# 3           25-34 years old
# 4           25-34 years old
#                 ...
# 89179       25-34 years old
# 89180       18-24 years old
# 89181     Prefer not to say
# 89182    Under 18 years old
# 89183       35-44 years old
# Name: Age, Length: 89184, dtype: object

# %%
df[(df.Age =='18-24 years old') ,['RemoteWork']]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Documents/Code/coding-tasks/python-samples/pandas-sample/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 89179    False
# 89180     True
# 89181    False
# 89182    False
# 89183    False
# Name: Age, Length: 89184, dtype: bool, ['RemoteWork'])' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# ...

# %%
df.loc[df['Age'] == '18-24 years old', ['RemoteWork']]
# Out:
#                                  RemoteWork
# 0                                       NaN
# 40     Hybrid (some remote, some in-person)
# 43     Hybrid (some remote, some in-person)
# 58                                      NaN
# 64                                In-person
# ...                                     ...
# 89167                                Remote
# 89168                                   NaN
# 89174                             In-person
# 89176                                   NaN
# 89180  Hybrid (some remote, some in-person)
#
# [17931 rows x 1 columns]

# %%
df.head(2)
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
#
#             Employment RemoteWork  \
# 0                  NaN        NaN
# 1  Employed, full-time     Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
#
#                                         EdLevel  \
# 0                                           NaN
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1  Books / Physical media;Colleague;Friend or fam...
#
#                                      LearnCodeOnline LearnCodeCoursesCert  \
# 0                                                NaN                  NaN
# ...

# %%
pd_schema.loc['CompTotal']
# Out:
# qid                                                       QID51
# question      What is your current total <b>annual</b> compe...
# force_resp                                                False
# type                                                         TE
# selector                                                     SL
# Name: CompTotal, dtype: object

# %%
df.CompTotal.count()
# Out:
# 48225

# %%
df.CompTotal.value_counts()
# Out:
# CompTotal
# 1.000000e+05    1355
# 6.000000e+04    1290
# 1.200000e+05    1240
# 1.500000e+05    1150
# 8.000000e+04    1066
#                 ...
# 1.642800e+06       1
# 1.380910e+05       1
# 2.957000e+04       1
# 4.190000e+05       1
# 3.300000e+09       1
# Name: count, Length: 3828, dtype: int64

# %%
df.loc[df.ConvertedCompYearly > 100000,['ConvertedCompYearly','Age','Industry','ProfessionalTech','WebframeHaveWorkedWith']].sort_values(by='ConvertedCompYearly', ascending=False)
# Out:
#        ConvertedCompYearly              Age  \
# 53268           74351432.0  18-24 years old
# 77848           73607918.0  35-44 years old
# 66223           72714292.0  55-64 years old
# 28121           57513831.0  25-34 years old
# 19679           36573181.0  25-34 years old
# ...                    ...              ...
# 60733             100086.0  25-34 years old
# 64059             100074.0  25-34 years old
# 17290             100074.0  35-44 years old
# 8038              100037.0  25-34 years old
# 25243             100037.0  35-44 years old
#
#                                                 Industry  \
# 53268  Information Services, IT, Software Development...
# 77848                                              Other
# 66223                                                NaN
# 28121                                 Financial Services
# 19679                                                NaN
# ...                                                  ...
# ...

# %%
df.iloc[53268]
# Out:
# ResponseId                                                                         53269
# Q120                                                                             I agree
# MainBranch                                                I am a developer by profession
# Age                                                                      18-24 years old
# Employment                             Independent contractor, freelancer, or self-em...
# RemoteWork                                          Hybrid (some remote, some in-person)
# CodingActivities                       Hobby;Contribute to open-source projects;Boots...
# EdLevel                                   Professional degree (JD, MD, Ph.D, Ed.D, etc.)
# LearnCode                              Friend or family member;Online Courses or Cert...
# LearnCodeOnline                        Formal documentation provided by the owner of ...
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df.at[2,'ConvertedCompYearly']
# Out:
# 250000.0

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
df.Employment.str.lower()
# Out:
# 0                                                      NaN
# 1                                      employed, full-time
# 2                                      employed, full-time
# 3                                      employed, full-time
# 4        employed, full-time;independent contractor, fr...
#                                ...
# 89179    employed, full-time;independent contractor, fr...
# 89180               student, full-time;employed, part-time
# 89181                                  i prefer not to say
# 89182               employed, part-time;student, part-time
# 89183                                  employed, full-time
# Name: Employment, Length: 89184, dtype: object

# %%
df["Employment"].str.contains("self").count()
# Out:
# 87898

# %%
def upper_case(email):
    return email.upper()

# %%
upper_case('TEST@GMAIL.COM')
# Out:
# 'test@gmail.com'

# %%
df["Employment"].apply(len)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df["Employment"].apply(len)
#
# File ~/Documents/Code/coding-tasks/python-samples/pandas-sample/.venv/lib/python3.12/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# ...

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df.head(1)
# Out:
#    ResponseId     Q120     MainBranch              Age Employment RemoteWork  \
# 0           1  I agree  None of these  18-24 years old        NaN        NaN
#
#   CodingActivities EdLevel LearnCode LearnCodeOnline  ... Frequency_1  \
# 0              NaN     NaN       NaN             NaN  ...         NaN
#
#   Frequency_2 Frequency_3 TimeSearching TimeAnswering ProfessionalTech  \
# 0         NaN         NaN           NaN           NaN              NaN
#
#   Industry SurveyLength SurveyEase ConvertedCompYearly
# 0      NaN          NaN        NaN                 NaN
#
# [1 rows x 84 columns]

# %%
df.MainBranch.apply(len)
# Out:
# 0        13
# 1        30
# 2        30
# 3        30
# 4        30
#          ..
# 89179    30
# 89180    30
# 89181    27
# 89182    30
# 89183    30
# Name: MainBranch, Length: 89184, dtype: int64

# %%
df.MainBranch.apply(upper_case)
# Out:
# 0                         NONE OF THESE
# 1        I AM A DEVELOPER BY PROFESSION
# 2        I AM A DEVELOPER BY PROFESSION
# 3        I AM A DEVELOPER BY PROFESSION
# 4        I AM A DEVELOPER BY PROFESSION
#                       ...
# 89179    I AM A DEVELOPER BY PROFESSION
# 89180    I AM A DEVELOPER BY PROFESSION
# 89181       I CODE PRIMARILY AS A HOBBY
# 89182    I AM A DEVELOPER BY PROFESSION
# 89183    I AM A DEVELOPER BY PROFESSION
# Name: MainBranch, Length: 89184, dtype: object

# %%
df.MainBranch = df.MainBranch.apply(upper_case)

# %%
df.head(1)
# Out:
#    ResponseId     Q120     MainBranch              Age Employment RemoteWork  \
# 0           1  I agree  NONE OF THESE  18-24 years old        NaN        NaN
#
#   CodingActivities EdLevel LearnCode LearnCodeOnline  ... Frequency_1  \
# 0              NaN     NaN       NaN             NaN  ...         NaN
#
#   Frequency_2 Frequency_3 TimeSearching TimeAnswering ProfessionalTech  \
# 0         NaN         NaN           NaN           NaN              NaN
#
#   Industry SurveyLength SurveyEase ConvertedCompYearly
# 0      NaN          NaN        NaN                 NaN
#
# [1 rows x 84 columns]

# %%
df.notna()
# Out:
#        ResponseId  Q120  MainBranch   Age  Employment  RemoteWork  \
# 0            True  True        True  True       False       False
# 1            True  True        True  True        True        True
# 2            True  True        True  True        True        True
# 3            True  True        True  True        True        True
# 4            True  True        True  True        True        True
# ...           ...   ...         ...   ...         ...         ...
# 89179        True  True        True  True        True        True
# 89180        True  True        True  True        True        True
# 89181        True  True        True  True        True       False
# 89182        True  True        True  True        True        True
# 89183        True  True        True  True        True        True
#
#        CodingActivities  EdLevel  LearnCode  LearnCodeOnline  ...  \
# 0                 False    False      False            False  ...
# ...

# %%
df.MainBranch = df.MainBranch.apply(lambda x: x.lower())

# %%
df.head(1)
# Out:
#    ResponseId     Q120     MainBranch              Age Employment RemoteWork  \
# 0           1  I agree  none of these  18-24 years old        NaN        NaN
#
#   CodingActivities EdLevel LearnCode LearnCodeOnline  ... Frequency_1  \
# 0              NaN     NaN       NaN             NaN  ...         NaN
#
#   Frequency_2 Frequency_3 TimeSearching TimeAnswering ProfessionalTech  \
# 0         NaN         NaN           NaN           NaN              NaN
#
#   Industry SurveyLength SurveyEase ConvertedCompYearly
# 0      NaN          NaN        NaN                 NaN
#
# [1 rows x 84 columns]

# %%
df.apply(len)
# Out:
# ResponseId             89184
# Q120                   89184
# MainBranch             89184
# Age                    89184
# Employment             89184
#                        ...
# ProfessionalTech       89184
# Industry               89184
# SurveyLength           89184
# SurveyEase             89184
# ConvertedCompYearly    89184
# Length: 84, dtype: int64

# %%
df.apply(len,axis='rows')
# Out:
# ResponseId             89184
# Q120                   89184
# MainBranch             89184
# Age                    89184
# Employment             89184
#                        ...
# ProfessionalTech       89184
# Industry               89184
# SurveyLength           89184
# SurveyEase             89184
# ConvertedCompYearly    89184
# Length: 84, dtype: int64

# %%
df.applymap(len)
# Out:
# /var/folders/yh/29sts6ss3dg9jkw19vq1d4yw0000gn/T/ipykernel_1048/1485728669.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(len)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 df.applymap(len)
#
# File ~/Documents/Code/coding-tasks/python-samples/pandas-sample/.venv/lib/python3.12/site-packages/pandas/core/frame.py:10522, in DataFrame.applymap(self, func, na_action, **kwargs)
#   10473 """
#   10474 Apply a function to a Dataframe elementwise.
#   10475
#    (...)
#   10515 1  5  5
#   10516 """
#   10517 warnings.warn(
#   10518     "DataFrame.applymap has been deprecated. Use DataFrame.map instead.",
#   10519     FutureWarning,
#   10520     stacklevel=find_stack_level(),
#   10521 )
# > 10522 return self.map(func, na_action=na_action, **kwargs)
#
# ...

# %%
df.map(len)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df.map(len)
#
# File ~/Documents/Code/coding-tasks/python-samples/pandas-sample/.venv/lib/python3.12/site-packages/pandas/core/frame.py:10468, in DataFrame.map(self, func, na_action, **kwargs)
#   10465 def infer(x):
#   10466     return x._map_values(func, na_action=na_action)
# > 10468 return self.apply(infer).__finalize__(self, "map")
#
# File ~/Documents/Code/coding-tasks/python-samples/pandas-sample/.venv/lib/python3.12/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# ...

# %%
df.map(str)
# Out:
#       ResponseId     Q120                      MainBranch                 Age  \
# 0              1  I agree                   none of these     18-24 years old
# 1              2  I agree  i am a developer by profession     25-34 years old
# 2              3  I agree  i am a developer by profession     45-54 years old
# 3              4  I agree  i am a developer by profession     25-34 years old
# 4              5  I agree  i am a developer by profession     25-34 years old
# ...          ...      ...                             ...                 ...
# 89179      89180  I agree  i am a developer by profession     25-34 years old
# 89180      89181  I agree  i am a developer by profession     18-24 years old
# 89181      89182  I agree     i code primarily as a hobby   Prefer not to say
# 89182      89183  I agree  i am a developer by profession  Under 18 years old
# 89183      89184  I agree  i am a developer by profession     35-44 years old
#
# ...

# %%
df.map(str).map(len)
# Out:
#        ResponseId  Q120  MainBranch  Age  Employment  RemoteWork  \
# 0               1     7          13   15           3           3
# 1               1     7          30   15          19           6
# 2               1     7          30   15          19          36
# 3               1     7          30   15          19          36
# 4               1     7          30   15          72           6
# ...           ...   ...         ...  ...         ...         ...
# 89179           5     7          30   15          72           6
# 89180           5     7          30   15          38          36
# 89181           5     7          27   17          19           3
# 89182           5     7          30   18          38          36
# 89183           5     7          30   15          19          36
#
#        CodingActivities  EdLevel  LearnCode  LearnCodeOnline  ...  \
# 0                     3        3          3                3  ...
# ...

# %%
df.rename(columns={'ConvertedCompYearly' :'SalaryInUSD'},inplace=True)

# %%
df.head(1)
# Out:
#    ResponseId     Q120     MainBranch              Age Employment RemoteWork  \
# 0           1  I agree  None of these  18-24 years old        NaN        NaN
#
#   CodingActivities EdLevel LearnCode LearnCodeOnline  ... Frequency_1  \
# 0              NaN     NaN       NaN             NaN  ...         NaN
#
#   Frequency_2 Frequency_3 TimeSearching TimeAnswering ProfessionalTech  \
# 0         NaN         NaN           NaN           NaN              NaN
#
#   Industry SurveyLength SurveyEase SalaryInUSD
# 0      NaN          NaN        NaN         NaN
#
# [1 rows x 84 columns]

# %%
df.Q120
# Out:
# 0        I agree
# 1        I agree
# 2        I agree
# 3        I agree
# 4        I agree
#           ...
# 89179    I agree
# 89180    I agree
# 89181    I agree
# 89182    I agree
# 89183    I agree
# Name: Q120, Length: 89184, dtype: object

# %%
df['Q120'].value_counts()
# Out:
# Q120
# I agree    89184
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#    ResponseId     Q120                      MainBranch              Age  \
# 0           1  I agree                   None of these  18-24 years old
# 1           2  I agree  I am a developer by profession  25-34 years old
#
#             Employment RemoteWork  \
# 0                  NaN        NaN
# 1  Employed, full-time     Remote
#
#                                     CodingActivities  \
# 0                                                NaN
# 1  Hobby;Contribute to open-source projects;Boots...
#
#                                         EdLevel  \
# 0                                           NaN
# 1  Bachelor’s degree (B.A., B.S., B.Eng., etc.)
#
#                                            LearnCode  \
# 0                                                NaN
# 1  Books / Physical media;Colleague;Friend or fam...
#
#                                      LearnCodeOnline  ...       Frequency_1  \
# 0                                                NaN  ...               NaN
# ...

# %%
df['RemoteWork'].value_counts()
# Out:
# RemoteWork
# Hybrid (some remote, some in-person)    31131
# Remote                                  30566
# In-person                               12113
# Name: count, dtype: int64

# %%
df['RemoteWork'] = df['RemoteWork'].map({'Hybrid (some remote, some in-person)' : False}, {'Remote' :True} , {'In-person', False})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df['RemoteWork'] = df['RemoteWork'].map({'Hybrid (some remote, some in-person)' : False}, {'Remote' :True} , {'In-person', False})
#
# TypeError: Series.map() takes from 2 to 3 positional arguments but 4 were given

# %%
def update_remote_working(remote_work):
    if 'Remote' in str(remote_work):
        return True
    return False

# %%
df['RemoteWork'] = df['RemoteWork'].map(update_remote_working)

# %%
df['RemoteWork']
# Out:
# 0                                         NaN
# 1                                      Remote
# 2        Hybrid (some remote, some in-person)
# 3        Hybrid (some remote, some in-person)
# 4                                      Remote
#                          ...
# 89179                                  Remote
# 89180    Hybrid (some remote, some in-person)
# 89181                                     NaN
# 89182    Hybrid (some remote, some in-person)
# 89183    Hybrid (some remote, some in-person)
# Name: RemoteWork, Length: 89184, dtype: object

# %%
df.head(100)
# Out:
#     ResponseId     Q120                      MainBranch              Age  \
# 0            1  I agree                   None of these  18-24 years old
# 1            2  I agree  I am a developer by profession  25-34 years old
# 2            3  I agree  I am a developer by profession  45-54 years old
# 3            4  I agree  I am a developer by profession  25-34 years old
# 4            5  I agree  I am a developer by profession  25-34 years old
# ..         ...      ...                             ...              ...
# 95          96  I agree  I am a developer by profession  18-24 years old
# 96          97  I agree  I am a developer by profession  25-34 years old
# 97          98  I agree  I am a developer by profession  25-34 years old
# 98          99  I agree  I am a developer by profession  35-44 years old
# 99         100  I agree  I am a developer by profession  25-34 years old
#
#                                            Employment  RemoteWork  \
# ...

# %%
df['SalaryInUSD'].sort_values()
# Out:
# 8862     1.0
# 55664    1.0
# 54023    1.0
# 63213    1.0
# 13708    1.0
#         ...
# 89179    NaN
# 89180    NaN
# 89181    NaN
# 89182    NaN
# 89183    NaN
# Name: SalaryInUSD, Length: 89184, dtype: float64

# %%
df.sort_values(by=['SalaryInUSD','Age'],ascending=[False,True],inplace=True)

# %%
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 53268       53269  I agree  I am a developer by profession
# 77848       77849  I agree  I am a developer by profession
# 66223       66224  I agree  I am a developer by profession
# 28121       28122  I agree  I am a developer by profession
# 19679       19680  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89065       89066  I agree     I code primarily as a hobby
# 89074       89075  I agree     I code primarily as a hobby
# 89096       89097  I agree           I am learning to code
# 89134       89135  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 53268     18-24 years old  Independent contractor, freelancer, or self-em...
# 77848     35-44 years old                                I prefer not to say
# ...

# %%
df[['Age','SalaryInUSD']]
# Out:
#                       Age  SalaryInUSD
# 53268     18-24 years old   74351432.0
# 77848     35-44 years old   73607918.0
# 66223     55-64 years old   72714292.0
# 28121     25-34 years old   57513831.0
# 19679     25-34 years old   36573181.0
# ...                   ...          ...
# 89065  Under 18 years old          NaN
# 89074  Under 18 years old          NaN
# 89096  Under 18 years old          NaN
# 89134  Under 18 years old          NaN
# 89182  Under 18 years old          NaN
#
# [89184 rows x 2 columns]

# %%
df.nlargest(10,'SalaryInUSD')
# Out:
#        ResponseId     Q120                                         MainBranch  \
# 53268       53269  I agree                     I am a developer by profession
# 77848       77849  I agree                     I am a developer by profession
# 66223       66224  I agree                     I am a developer by profession
# 28121       28122  I agree                     I am a developer by profession
# 19679       19680  I agree                     I am a developer by profession
# 55102       55103  I agree  I am not primarily a developer, but I write co...
# 80586       80587  I agree                     I am a developer by profession
# 83679       83680  I agree                     I am a developer by profession
# 47797       47798  I agree                     I am a developer by profession
# 88347       88348  I agree                     I am a developer by profession
#
#                       Age                                         Employment  \
# ...

# %%
df.median()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 df.median()
#
# File ~/Documents/Code/coding-tasks/python-samples/pandas-sample/.venv/lib/python3.12/site-packages/pandas/core/frame.py:11706, in DataFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11698 @doc(make_doc("median", ndim=2))
#   11699 def median(
#   11700     self,
#    (...)
#   11704     **kwargs,
#   11705 ):
# > 11706     result = super().median(axis, skipna, numeric_only, **kwargs)
#   11707     if isinstance(result, Series):
#   11708         result = result.__finalize__(self, method="median")
#
# File ~/Documents/Code/coding-tasks/python-samples/pandas-sample/.venv/lib/python3.12/site-packages/pandas/core/generic.py:12431, in NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   12424 def median(
#   12425     self,
#   12426     axis: Axis | None = 0,
# ...

# %%
df.describe()
# Out:
#          ResponseId     CompTotal       WorkExp   SalaryInUSD
# count  89184.000000  4.822500e+04  43579.000000  4.801900e+04
# mean   44592.500000  1.036807e+42     11.405126  1.031101e+05
# std    25745.347541  2.276847e+44      9.051989  6.814188e+05
# min        1.000000  0.000000e+00      0.000000  1.000000e+00
# 25%    22296.750000  6.300000e+04      5.000000  4.390700e+04
# 50%    44592.500000  1.150000e+05      9.000000  7.496300e+04
# 75%    66888.250000  2.300000e+05     16.000000  1.216410e+05
# max    89184.000000  5.000000e+46     50.000000  7.435143e+07

# %%
df.columns
# Out:
# Index(['ResponseId', 'Q120', 'MainBranch', 'Age', 'Employment', 'RemoteWork',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'LearnCodeCoursesCert', 'YearsCode', 'YearsCodePro', 'DevType',
#        'OrgSize', 'PurchaseInfluence', 'TechList', 'BuyNewTool', 'Country',
#        'Currency', 'CompTotal', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'NEWCollabToolsHaveWorkedWith',
#        'NEWCollabToolsWantToWorkWith', 'OpSysPersonal use',
#        'OpSysProfessional use', 'OfficeStackAsyncHaveWorkedWith',
#        'OfficeStackAsyncWantToWorkWith', 'OfficeStackSyncHaveWorkedWith',
# ...

# %%
df['Industry']
# Out:
# 53268    Information Services, IT, Software Development...
# 77848                                                Other
# 66223                                                  NaN
# 28121                                   Financial Services
# 19679                                                  NaN
#                                ...
# 89065                                                  NaN
# 89074                                                  NaN
# 89096                                                  NaN
# 89134                                                  NaN
# 89182                                                  NaN
# Name: Industry, Length: 89184, dtype: object

# %%
df['Age'].value_counts(normalize=True)
# Out:
# Age
# 25-34 years old       0.372791
# 35-44 years old       0.230221
# 18-24 years old       0.201056
# 45-54 years old       0.093447
# Under 18 years old    0.046286
# 55-64 years old       0.038034
# 65 years or older     0.013130
# Prefer not to say     0.005035
# Name: proportion, dtype: float64

# %%
g = df.groupby(['Industry'])

# %%
g

# %%
g.Age

# %%
g.Country

# %%
g.get_group('Financial Services')
# Out:
# /var/folders/yh/29sts6ss3dg9jkw19vq1d4yw0000gn/T/ipykernel_1370/2482469607.py:1: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   g.get_group('Financial Services')
#        ResponseId     Q120                                         MainBranch  \
# 28121       28122  I agree                     I am a developer by profession
# 51182       51183  I agree                     I am a developer by profession
# 32596       32597  I agree                     I am a developer by profession
# 51714       51715  I agree  I am not primarily a developer, but I write co...
# 25842       25843  I agree                     I am a developer by profession
# ...           ...      ...                                                ...
# 69181       69182  I agree                     I am a developer by profession
# ...

# %%
g['Age'].value_counts().sort_values(ascending=False).head(5)
# Out:
# Industry                                                             Age
# Information Services, IT, Software Development, or other Technology  25-34 years old    8437
#                                                                      35-44 years old    4982
#                                                                      18-24 years old    2494
# Financial Services                                                   25-34 years old    2138
# Other                                                                25-34 years old    1856
# Name: count, dtype: int64

# %%
g['Age'].value_counts().median()
# Out:
# 69.0

# %%
g['SalaryInUSD'].value_counts(normalize=True).agg(['median','mean'])
# Out:
# median    0.000332
# mean      0.001055
# Name: proportion, dtype: float64

# %%
fil = df['ProfessionalTech'].str.contains('Web') == True
fil.sum()
# Out:
# 0

# %%
df['ProfessionalTech']
# Out:
# 53268    Developer portal or other central places to fi...
# 77848    DevOps function;Microservices;Automated testin...
# 66223                                                  NaN
# 28121    Continuous integration (CI) and (more often) c...
# 19679                                                  NaN
#                                ...
# 89065                                                  NaN
# 89074                                                  NaN
# 89096                                                  NaN
# 89134                                                  NaN
# 89182                                                  NaN
# Name: ProfessionalTech, Length: 89184, dtype: object

# %%
gg = df.groupby(['Country'])

# %%
# Out:
# Series([], Name: count, dtype: int64)

# %%
lg = df.groupby(['Country','LanguageHaveWorkedWith' , 'Age'])
lg.get_group(('United States of America','JavaScript','18-24 years old')).describe()
# Out:
#          ResponseId      CompTotal  WorkExp  ConvertedCompYearly
# count      2.000000       2.000000      1.0             2.000000
# mean   57245.000000  143000.000000      1.0        143000.000000
# std    34542.166261   38183.766184      NaN         38183.766184
# min    32820.000000  116000.000000      1.0        116000.000000
# 25%    45032.500000  129500.000000      1.0        129500.000000
# 50%    57245.000000  143000.000000      1.0        143000.000000
# 75%    69457.500000  156500.000000      1.0        156500.000000
# max    81670.000000  170000.000000      1.0        170000.000000

# %%
gg['LanguageHaveWorkedWith'].value_counts().sort_values(ascending=False).head(5)
# Out:
# Country                   LanguageHaveWorkedWith
# United States of America  HTML/CSS;JavaScript;TypeScript           208
#                           Python                                   196
# India                     HTML/CSS;JavaScript;TypeScript           172
# United States of America  C#;HTML/CSS;JavaScript;SQL;TypeScript    143
#                           C#;HTML/CSS;JavaScript;SQL               123
# Name: count, dtype: int64
